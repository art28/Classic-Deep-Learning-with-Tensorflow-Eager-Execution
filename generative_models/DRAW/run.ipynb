# %%
import numpy as np
import tensorflow as tf
import tensorflow.contrib.eager as tfe
import matplotlib.pyplot as plt

# %matplotlib inline

tfe.enable_eager_execution(device_policy = tfe.DEVICE_PLACEMENT_SILENT)

# %%
from model import DRAW

# %%
device = 'gpu:0' if tfe.num_gpus() > 0 else 'cpu:0'

# %%
z_dim = 10

# %%
draw = DRAW(device_name=device, learning_rate=1e-3, z_dim=z_dim)

# %%
# if you already have pretrained model
# draw.load(global_step="latest")

# %%
from tensorflow.python.keras.datasets import mnist

(x_train, y_train), (x_test, y_test) = mnist.load_data()
x_train = x_train.astype('float32') / 255.
x_train = x_train.reshape((x_train.shape[0], 28 * 28))
ds_train = tf.data.Dataset.from_tensor_slices((x_train,))

# %%
def drawingtest():
    testset = x_test[:10,:,:]      
    img_orig = testset.reshape(-1,28,28)
    img_orig = np.concatenate(img_orig, axis=1)
       
    input_test = testset.astype('float32')/255.
    input_test = input_test.reshape(-1, 28*28)
    input_test = tf.convert_to_tensor(input_test)
    
    plt.imshow(img_orig, cmap="gray")
    plt.show()
    
    z = draw.extract(input_test)
    canvases = draw.draw(z)
    for canvas in canvases:
        img_test = tf.nn.sigmoid(canvas).numpy().reshape(-1,28,28)
        img_test = np.concatenate(img_test, axis=1)

        plt.imshow(img_test, cmap="gray")
        plt.show()

# %%
drawingtest()

# %%
# if you want to train
for i in range(20):
    draw.fit(ds_train, saving=True, epochs=5, batch_size=256, verbose=1)
    drawingtest()
# Out:
# [EPOCH 1 / STEP 1]
# TRAIN loss   : 53600.0820
# RECON loss   : 52578.2773
# KL    loss   : 1021.7837
# =========================
# [EPOCH 2 / STEP 2]
# TRAIN loss   : 44543.9609
# RECON loss   : 43232.8320
# KL    loss   : 1311.1503
# =========================
# [EPOCH 3 / STEP 3]
# TRAIN loss   : 38988.1016
# RECON loss   : 36336.1719
# KL    loss   : 2651.9272
# =========================
# [EPOCH 4 / STEP 4]
# TRAIN loss   : 35708.2734
# RECON loss   : 32172.9062
# KL    loss   : 3535.3667
# =========================
# [EPOCH 5 / STEP 5]
# TRAIN loss   : 33396.1016
# RECON loss   : 29140.4043
# KL    loss   : 4255.6904
# =========================
# [EPOCH 1 / STEP 6]
# TRAIN loss   : 31543.1348
# RECON loss   : 26790.4473
# KL    loss   : 4752.6851
# =========================
# [EPOCH 2 / STEP 7]
# TRAIN loss   : 30392.0234
# RECON loss   : 25407.8379
# KL    loss   : 4984.2017
# =========================
# [EPOCH 3 / STEP 8]
# TRAIN loss   : 29480.2598
# RECON loss   : 24313.4277
# KL    loss   : 5166.8247
# =========================
# [EPOCH 4 / STEP 9]
# TRAIN loss   : 28925.6680
# RECON loss   : 23641.3262
# KL    loss   : 5284.3408
# =========================
# [EPOCH 5 / STEP 10]
# TRAIN loss   : 28442.0117
# RECON loss   : 23055.3574
# KL    loss   : 5386.6475
# =========================
# [EPOCH 1 / STEP 11]
# TRAIN loss   : 27965.2246
# RECON loss   : 22529.0762
# KL    loss   : 5436.1445
# =========================
# [EPOCH 2 / STEP 12]
# TRAIN loss   : 27666.7383
# RECON loss   : 22172.2812
# KL    loss   : 5494.4634
# =========================
# [EPOCH 3 / STEP 13]
# TRAIN loss   : 27375.3203
# RECON loss   : 21844.1074
# KL    loss   : 5531.2085
# =========================
# [EPOCH 4 / STEP 14]
# TRAIN loss   : 27118.5684
# RECON loss   : 21558.6289
# KL    loss   : 5559.9531
# =========================
# [EPOCH 5 / STEP 15]
# TRAIN loss   : 26881.4844
# RECON loss   : 21312.0039
# KL    loss   : 5569.4902
# =========================
# [EPOCH 1 / STEP 16]
# TRAIN loss   : 26709.9512
# RECON loss   : 21117.5645
# KL    loss   : 5592.3892
# =========================
# [EPOCH 2 / STEP 17]
# TRAIN loss   : 26523.0645
# RECON loss   : 20926.0508
# KL    loss   : 5597.0059
# =========================
# [EPOCH 3 / STEP 18]
# TRAIN loss   : 26366.2422
# RECON loss   : 20768.2012
# KL    loss   : 5598.0469
# =========================
# [EPOCH 4 / STEP 19]
# TRAIN loss   : 26262.6133
# RECON loss   : 20647.7168
# KL    loss   : 5614.8813
# =========================
# [EPOCH 5 / STEP 20]
# TRAIN loss   : 26058.5820
# RECON loss   : 20454.8203
# KL    loss   : 5603.7563
# =========================
# [EPOCH 1 / STEP 21]
# TRAIN loss   : 25932.1504
# RECON loss   : 20326.3730
# KL    loss   : 5605.7720
# =========================
# [EPOCH 2 / STEP 22]
# TRAIN loss   : 25800.6328
# RECON loss   : 20201.8223
# KL    loss   : 5598.8135
# =========================
# [EPOCH 3 / STEP 23]
# TRAIN loss   : 25693.3535
# RECON loss   : 20085.9258
# KL    loss   : 5607.4243
# =========================
# [EPOCH 4 / STEP 24]
# TRAIN loss   : 25563.3086
# RECON loss   : 19952.3164
# KL    loss   : 5611.0068
# =========================
# [EPOCH 5 / STEP 25]
# TRAIN loss   : 25425.6641
# RECON loss   : 19828.7891
# KL    loss   : 5596.8843
# =========================
# [EPOCH 1 / STEP 26]
# TRAIN loss   : 25313.8281
# RECON loss   : 19714.5801
# KL    loss   : 5599.2539
# =========================
# [EPOCH 2 / STEP 27]
# TRAIN loss   : 25255.2559
# RECON loss   : 19651.6445
# KL    loss   : 5603.6099
# =========================
# [EPOCH 3 / STEP 28]
# TRAIN loss   : 25126.8555
# RECON loss   : 19527.5352
# KL    loss   : 5599.3232
# =========================
# [EPOCH 4 / STEP 29]
# TRAIN loss   : 25039.0586
# RECON loss   : 19452.1719
# KL    loss   : 5586.8853
# =========================
# [EPOCH 5 / STEP 30]
# TRAIN loss   : 24970.6621
# RECON loss   : 19385.5039
# KL    loss   : 5585.1685
# =========================
# [EPOCH 1 / STEP 31]
# TRAIN loss   : 24879.9492
# RECON loss   : 19305.0234
# KL    loss   : 5574.9248
# =========================
# [EPOCH 2 / STEP 32]
# TRAIN loss   : 24797.9043
# RECON loss   : 19224.1016
# KL    loss   : 5573.8096
# =========================
# [EPOCH 3 / STEP 33]
# TRAIN loss   : 24736.9297
# RECON loss   : 19162.8008
# KL    loss   : 5574.1128
# =========================
# [EPOCH 4 / STEP 34]
# TRAIN loss   : 24651.1016
# RECON loss   : 19088.8906
# KL    loss   : 5562.1992
# =========================
# [EPOCH 5 / STEP 35]
# TRAIN loss   : 24555.8672
# RECON loss   : 19000.2402
# KL    loss   : 5555.6338
# =========================
# [EPOCH 1 / STEP 36]
# TRAIN loss   : 24497.2891
# RECON loss   : 18955.4414
# KL    loss   : 5541.8447
# =========================
# [EPOCH 2 / STEP 37]
# TRAIN loss   : 24452.1934
# RECON loss   : 18911.8477
# KL    loss   : 5540.3418
# =========================
# [EPOCH 3 / STEP 38]
# TRAIN loss   : 24396.1152
# RECON loss   : 18851.1309
# KL    loss   : 5544.9834
# =========================
# [EPOCH 4 / STEP 39]
# TRAIN loss   : 24305.0195
# RECON loss   : 18772.3691
# KL    loss   : 5532.6597
# =========================
# [EPOCH 5 / STEP 40]
# TRAIN loss   : 24235.3359
# RECON loss   : 18713.3398
# KL    loss   : 5521.9839
# =========================
# [EPOCH 1 / STEP 41]
# TRAIN loss   : 24203.7012
# RECON loss   : 18677.3555
# KL    loss   : 5526.3481
# =========================
# [EPOCH 2 / STEP 42]
# TRAIN loss   : 24147.8945
# RECON loss   : 18624.7051
# KL    loss   : 5523.1895
# =========================
# [EPOCH 3 / STEP 43]
# TRAIN loss   : 24102.8047
# RECON loss   : 18583.6719
# KL    loss   : 5519.1367
# =========================
# [EPOCH 4 / STEP 44]
# TRAIN loss   : 24043.2871
# RECON loss   : 18530.2285
# KL    loss   : 5513.0645
# =========================
# [EPOCH 5 / STEP 45]
# TRAIN loss   : 23972.8340
# RECON loss   : 18477.4180
# KL    loss   : 5495.4131
# =========================
# [EPOCH 1 / STEP 46]
# TRAIN loss   : 23956.1855
# RECON loss   : 18460.5723
# KL    loss   : 5495.6040
# =========================
# [EPOCH 2 / STEP 47]
# TRAIN loss   : 23901.7930
# RECON loss   : 18407.4785
# KL    loss   : 5494.3193
# =========================
# [EPOCH 3 / STEP 48]
# TRAIN loss   : 23866.9375
# RECON loss   : 18379.2520
# KL    loss   : 5487.6929
# =========================
# [EPOCH 4 / STEP 49]
# TRAIN loss   : 23801.7090
# RECON loss   : 18319.4160
# KL    loss   : 5482.3052
# =========================
# [EPOCH 5 / STEP 50]
# TRAIN loss   : 23758.2520
# RECON loss   : 18284.6465
# KL    loss   : 5473.5991
# =========================
# [EPOCH 1 / STEP 51]
# TRAIN loss   : 23708.6621
# RECON loss   : 18240.0684
# KL    loss   : 5468.5781
# =========================
# [EPOCH 2 / STEP 52]
# TRAIN loss   : 23682.3184
# RECON loss   : 18216.0547
# KL    loss   : 5466.2646
# =========================
# [EPOCH 3 / STEP 53]
# TRAIN loss   : 23642.4668
# RECON loss   : 18185.3926
# KL    loss   : 5457.0688
# =========================
# [EPOCH 4 / STEP 54]
# TRAIN loss   : 23600.8887
# RECON loss   : 18147.3301
# KL    loss   : 5453.5596
# =========================
# [EPOCH 5 / STEP 55]
# TRAIN loss   : 23545.9316
# RECON loss   : 18105.1621
# KL    loss   : 5440.7661
# =========================
# [EPOCH 1 / STEP 56]
# TRAIN loss   : 23535.6699
# RECON loss   : 18086.2012
# KL    loss   : 5449.4556
# =========================
# [EPOCH 2 / STEP 57]
# TRAIN loss   : 23496.8320
# RECON loss   : 18054.4668
# KL    loss   : 5442.3760
# =========================
# [EPOCH 3 / STEP 58]
# TRAIN loss   : 23449.5488
# RECON loss   : 18004.7656
# KL    loss   : 5444.7871
# =========================
# [EPOCH 4 / STEP 59]
# TRAIN loss   : 23423.8711
# RECON loss   : 17989.3477
# KL    loss   : 5434.5186
# =========================
# [EPOCH 5 / STEP 60]
# TRAIN loss   : 23380.5508
# RECON loss   : 17951.7266
# KL    loss   : 5428.8286
# =========================
# [EPOCH 1 / STEP 61]
# TRAIN loss   : 23344.1113
# RECON loss   : 17924.1387
# KL    loss   : 5419.9756
# =========================
# [EPOCH 2 / STEP 62]
# TRAIN loss   : 23316.4590
# RECON loss   : 17896.0645
# KL    loss   : 5420.3950
# =========================
# [EPOCH 3 / STEP 63]
# TRAIN loss   : 23279.2656
# RECON loss   : 17866.9355
# KL    loss   : 5412.3369
# =========================
# [EPOCH 4 / STEP 64]
# TRAIN loss   : 23281.1270
# RECON loss   : 17863.0547
# KL    loss   : 5418.0625
# =========================
# [EPOCH 5 / STEP 65]
# TRAIN loss   : 23238.4805
# RECON loss   : 17825.5176
# KL    loss   : 5412.9717
# =========================
# [EPOCH 1 / STEP 66]
# TRAIN loss   : 23198.8184
# RECON loss   : 17791.1035
# KL    loss   : 5407.7124
# =========================
# [EPOCH 2 / STEP 67]
# TRAIN loss   : 23205.4258
# RECON loss   : 17793.2969
# KL    loss   : 5412.1250
# =========================
# [EPOCH 3 / STEP 68]
# TRAIN loss   : 23140.7812
# RECON loss   : 17740.0625
# KL    loss   : 5400.7158
# =========================
# [EPOCH 4 / STEP 69]
# TRAIN loss   : 23130.0957
# RECON loss   : 17738.5078
# KL    loss   : 5391.5942
# =========================
# [EPOCH 5 / STEP 70]
# TRAIN loss   : 23102.0508
# RECON loss   : 17699.9336
# KL    loss   : 5402.1313
# =========================
# [EPOCH 1 / STEP 71]
# TRAIN loss   : 23091.6797
# RECON loss   : 17696.6562
# KL    loss   : 5395.0283
# =========================
# [EPOCH 2 / STEP 72]
# TRAIN loss   : 23051.3594
# RECON loss   : 17664.9688
# KL    loss   : 5386.3931
# =========================
# [EPOCH 3 / STEP 73]
# TRAIN loss   : 23018.0020
# RECON loss   : 17636.4902
# KL    loss   : 5381.5112
# =========================
# [EPOCH 4 / STEP 74]
# TRAIN loss   : 23022.9375
# RECON loss   : 17636.7910
# KL    loss   : 5386.1489
# =========================
# [EPOCH 5 / STEP 75]
# TRAIN loss   : 22985.5020
# RECON loss   : 17602.6406
# KL    loss   : 5382.8516
# =========================
# [EPOCH 1 / STEP 76]
# TRAIN loss   : 22945.2266
# RECON loss   : 17567.6816
# KL    loss   : 5377.5513
# =========================
# [EPOCH 2 / STEP 77]
# TRAIN loss   : 22941.6191
# RECON loss   : 17574.5703
# KL    loss   : 5367.0566
# =========================
# [EPOCH 3 / STEP 78]
# TRAIN loss   : 22930.4785
# RECON loss   : 17558.4082
# KL    loss   : 5372.0635
# =========================
# [EPOCH 4 / STEP 79]
# TRAIN loss   : 22911.7363
# RECON loss   : 17543.0371
# KL    loss   : 5368.7095
# =========================
# [EPOCH 5 / STEP 80]
# TRAIN loss   : 22870.2871
# RECON loss   : 17504.5918
# KL    loss   : 5365.6846
# =========================
# [EPOCH 1 / STEP 81]
# TRAIN loss   : 22858.6035
# RECON loss   : 17503.2090
# KL    loss   : 5355.4053
# =========================
# [EPOCH 2 / STEP 82]
# TRAIN loss   : 22836.6289
# RECON loss   : 17470.4863
# KL    loss   : 5366.1553
# =========================
# [EPOCH 3 / STEP 83]
# TRAIN loss   : 22847.2148
# RECON loss   : 17478.6484
# KL    loss   : 5368.5674
# =========================
# [EPOCH 4 / STEP 84]
# TRAIN loss   : 22789.5996
# RECON loss   : 17438.6016
# KL    loss   : 5350.9976
# =========================
# [EPOCH 5 / STEP 85]
# TRAIN loss   : 22780.9316
# RECON loss   : 17424.8633
# KL    loss   : 5356.0762
# =========================
# [EPOCH 1 / STEP 86]
# TRAIN loss   : 22762.4531
# RECON loss   : 17410.5332
# KL    loss   : 5351.9131
# =========================
# [EPOCH 2 / STEP 87]
# TRAIN loss   : 22771.9375
# RECON loss   : 17419.4258
# KL    loss   : 5352.5088
# =========================
# [EPOCH 3 / STEP 88]
# TRAIN loss   : 22746.0664
# RECON loss   : 17395.9707
# KL    loss   : 5350.0972
# =========================
# [EPOCH 4 / STEP 89]
# TRAIN loss   : 22715.3613
# RECON loss   : 17374.4160
# KL    loss   : 5340.9497
# =========================
# [EPOCH 5 / STEP 90]
# TRAIN loss   : 22699.8066
# RECON loss   : 17359.3438
# KL    loss   : 5340.4707
# =========================
# [EPOCH 1 / STEP 91]
# TRAIN loss   : 22678.1133
# RECON loss   : 17339.5215
# KL    loss   : 5338.5967
# =========================
# [EPOCH 2 / STEP 92]
# TRAIN loss   : 22669.3008
# RECON loss   : 17327.6660
# KL    loss   : 5341.6309
# =========================
# [EPOCH 3 / STEP 93]
# TRAIN loss   : 22664.0430
# RECON loss   : 17322.5508
# KL    loss   : 5341.4941
# =========================
# [EPOCH 4 / STEP 94]
# TRAIN loss   : 22649.1445
# RECON loss   : 17309.7051
# KL    loss   : 5339.4292
# =========================
# [EPOCH 5 / STEP 95]
# TRAIN loss   : 22616.7324
# RECON loss   : 17287.3340
# KL    loss   : 5329.3921
# =========================
# [EPOCH 1 / STEP 96]
# TRAIN loss   : 22631.0625
# RECON loss   : 17296.6562
# KL    loss   : 5334.4175
# =========================
# [EPOCH 2 / STEP 97]
# TRAIN loss   : 22581.7754
# RECON loss   : 17262.6250
# KL    loss   : 5319.1626
# =========================
# [EPOCH 3 / STEP 98]
# TRAIN loss   : 22589.4570
# RECON loss   : 17253.7344
# KL    loss   : 5335.7236
# =========================
# [EPOCH 4 / STEP 99]
# TRAIN loss   : 22575.8184
# RECON loss   : 17243.6152
# KL    loss   : 5332.2017
# =========================
# [EPOCH 5 / STEP 100]
# TRAIN loss   : 22551.6250
# RECON loss   : 17226.3164
# KL    loss   : 5325.3071
# =========================
